# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")

import pandas as pd
import matplotlib.pyplot as plt
from src.figures import scatter_matrix_linreg, corr_matrix

# %%
fphenotype = "../data/phenotype/phenotype_matrix.csv"

# %%
df = pd.read_csv(fphenotype, index_col=0)
# df.head()

# %%
fig = scatter_matrix_linreg(df, title="Scatter Matrix Phenotype")
fig.savefig("../report/figures/scatter_matrix.png", bbox_inches="tight")

# %%
fig = corr_matrix(df, title="Correlation Matrix")
fig.savefig("../report/figures/correlation_matrix.png", bbox_inches="tight")
