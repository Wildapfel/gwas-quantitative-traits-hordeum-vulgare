# %% [markdown]
# - Not working, somehow silverblue prevents the access to the os
# - Hence just run it trough terminal

# %%
import os

# %%
os.makedirs("../report/gapit/", exist_ok=True)

# %%
# %%bash
# #
# # Supposedly, /usr/bin should be accessible from here, but I believe that silverblue
# # prevents execution .... so I must execute GAPIT from the terminal:
# # cd to project dir
# # ./scripts/run_docker_GWAS.sh
# #
# ls -l /usr/bin/pwd
# ! export PATH="/usr/bin:$PATH"
# echo $PATH
# ls -la /usr/bin/docker
# Out:
# -rwxr-xr-x. 1 root root 36600 Jan  1  1970 /usr/bin/pwd
# /usr/bin:/var/home/max-inspiron/.micromamba/envs/bio-ml/bin:/var/home/max-inspiron/.micromamba/condabin:/var/home/max-inspiron/.local/bin:/var/home/max-inspiron/bin:/usr/local/sbin:/usr/local/bin:/usr/bin:/var/home/max-inspiron/.micromamba/condabin:/var/home/max-inspiron/.local/bin:/var/home/max-inspiron/bin:/usr/local/sbin:/usr/local/bin:/usr/bin
# -rwxr-xr-x. 1 root root 28402696 Jan  1  1970 /usr/bin/docker
