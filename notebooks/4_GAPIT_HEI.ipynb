# %% [markdown]
# - inspect GAPIT HEI outputs
# - selecting for significant markers

# %%
import pandas as pd
# import skimage.io as io

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
gapit_TGW = pd.read_csv("../data/gapit/GAPIT.Association.GWAS_Results.FarmCPU.HEI(NYC).csv")

# %%
# gapit_TGW.sort_values(by=["P.value"], ascending=True).head()
