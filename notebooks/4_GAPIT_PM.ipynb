# %% [markdown]
# - inspect GAPIT PM outputs
# - not selecting markers here, just curiosity

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
gapit_TGW = pd.read_csv("../data/gapit/GAPIT.Association.GWAS_Results.FarmCPU.PM(NYC).csv")

# %%
# gapit_TGW.sort_values(by=["P.value"],ascending=True).head()
