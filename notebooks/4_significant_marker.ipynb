# %% [markdown]
# - from the previous inspections i can now define some relevant markers

# %%
import pandas as pd

# %%
sigificant_markers = ["BK_15",
                      "BK_16",
                      "SCRI_RS_155612",
                      "SCRI_RS_133377",
                      "SCRI_RS_170337"]

# %%
# only using the lumns, allows me to directly echo the comma speration into the LD call
df = pd.DataFrame(columns=sigificant_markers)

# %%
df.to_csv("../data/significant_markers/significant_markers.csv")
